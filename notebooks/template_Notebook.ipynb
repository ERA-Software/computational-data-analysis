# %% [markdown]
# # Descriptive title

# %% [markdown]
# ## 📌 Overview
# In this tutorial, you will learn ...
#
# *(Optional) Add visual*
#
# ### 🧠 **Learning objectives**
# - xx
# - xx
#
# ### 🐍 **New in Python**
# - xx
# - xx
#
# ### 🌍 1. First-level block
# - **Second-level block**: Description
# - **Second-level block**: Description
#
# ...
